# %% [raw]
# imort pandas as pd

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Data=pd.read_csv("Census.csv")

# %%
Data
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %%
Data.drop("District_code", axis=1)
# Out:
#                       State_name              District_name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara      870354
# 1              JAMMU AND KASHMIR                     Badgam      753745
# 2              JAMMU AND KASHMIR                Leh(Ladakh)      133487
# 3              JAMMU AND KASHMIR                     Kargil      140802
# 4              JAMMU AND KASHMIR                      Punch      476835
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe       41816
# 636                  PONDICHERRY                   Karaikal      200222
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars       36842
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman      105597
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman      238142
#
#        Male  Female  Literate  Workers  Male_Workers  Female_Workers  \
# ...

# %%
Data[Data.District_name=="New Delhi"]
# Out:
#     District_code    State_name District_name  Population   Male  Female  \
# 93             94  NCT OF DELHI     New Delhi      142004  77942   64062
#
#     Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 93    114179    59541         46940           12601  ...        4852   2933
#
#     Buddhists  Jains  Secondary_Education  Higher_Education  \
# 93        312    679                15942             17742
#
#     Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 93               23934           76076            43913         21773
#
# [1 rows x 25 columns]

# %%
Data[Data.District_name=="Agra"]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 145            146  UTTAR PRADESH          Agra     4418797  2364953  2053844
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 145   2680510  1389844       1119701          270143  ...       10076  12057
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 145       4049  21508               450571            317618
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 145              199395         2871903           991255        547873
#
# [1 rows x 25 columns]

# %%
Data[Data.State_name=="UTTAR PRADESH"]
# Out:
#      District_code     State_name                 District_name  Population  \
# 131            132  UTTAR PRADESH                    Saharanpur     3466382
# 132            133  UTTAR PRADESH                 Muzaffarnagar     4143512
# 133            134  UTTAR PRADESH                        Bijnor     3682713
# 134            135  UTTAR PRADESH                     Moradabad     4772006
# 135            136  UTTAR PRADESH                        Rampur     2335819
# ..             ...            ...                           ...         ...
# 197            198  UTTAR PRADESH  Sant Ravidas Nagar (Bhadohi)     1578213
# 198            199  UTTAR PRADESH                      Mirzapur     2496970
# 199            200  UTTAR PRADESH                     Sonbhadra     1862559
# 200            201  UTTAR PRADESH                          Etah     1774480
# 201            202  UTTAR PRADESH               Kanshiram Nagar     1436719
#
# ...

# %%
A=Data[Data["District_name"].isin(["Agra","Etah"])]
A
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 145            146  UTTAR PRADESH          Agra     4418797  2364953  2053844
# 200            201  UTTAR PRADESH          Etah     1774480   947339   827141
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 145   2680510  1389844       1119701          270143  ...       10076  12057
# 200   1055202   545984        440244          105740  ...        2464    708
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 145       4049  21508               450571            317618
# 200       2887   5671               178434            119665
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 145              199395         2871903           991255        547873
# 200               88607         1149372           383707        237427
#
# [2 rows x 25 columns]

# %%
males=A["Male_Workers"]
female=A["Female_Workers"]
males
female
# Out:
# 145    1119701
# 200     440244
# Name: Male_Workers, dtype: int64

# %%
A["State_name"]
# Out:
# 145    UTTAR PRADESH
# 200    UTTAR PRADESH
# Name: State_name, dtype: object

# %%
Data[Data.State_name=="MAHARASHTRA"]["Male_Workers"].sum()
# Out:
# np.int64(32616875)

# %%
Data[Data.State_name=="UTTAR PRADESH"]["Male_Workers"].sum()
# Out:
# np.int64(49846762)

# %%
Data[Data.State_name=="PONDICHERRY"]["Male_Workers"].sum()
# Out:
# np.int64(332931)

# %%
Data[Data.State_name=="UTTAR PRADESH"]["Female_Workers"].sum()
# Out:
# np.int64(15967953)

# %%
Data.groupby("State_name").Population.sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
Data.groupby("State_name").Female_Workers.sum().sort_values(ascending=False)
# Out:
# State_name
# MAHARASHTRA                    16811003
# UTTAR PRADESH                  15967953
# ANDHRA PRADESH                 15237311
# RAJASTHAN                      11589179
# TAMIL NADU                     11449703
# MADHYA PRADESH                 11427163
# KARNATAKA                       9602481
# BIHAR                           9502798
# WEST BENGAL                     8040308
# GUJARAT                         6766833
# ORISSA                          5638934
# CHHATTISGARH                    5046359
# JHARKHAND                       4673505
# ASSAM                           3428130
# KERALA                          3167494
# HARYANA                         2109872
# PUNJAB                          1823205
# HIMACHAL PRADESH                1516049
# UTTARAKHAND                     1320354
# JAMMU AND KASHMIR               1127623
# NCT OF DELHI                     825023
# MANIPUR                          565202
# MEGHALAYA                        481910
# ...

# %%
Data.groupby("State_name")["Hindus"].sum().sort_values(ascending=False)
# Out:
# State_name
# UTTAR PRADESH                  159312654
# MAHARASHTRA                     89703057
# BIHAR                           86078686
# ANDHRA PRADESH                  74824149
# MADHYA PRADESH                  66007121
# WEST BENGAL                     64385546
# TAMIL NADU                      63188168
# RAJASTHAN                       60657103
# GUJARAT                         53533988
# KARNATAKA                       51317472
# ORISSA                          39300341
# CHHATTISGARH                    23819789
# JHARKHAND                       22376051
# HARYANA                         22171128
# ASSAM                           19180759
# KERALA                          18282492
# NCT OF DELHI                    13712100
# PUNJAB                          10678138
# UTTARAKHAND                      8368636
# HIMACHAL PRADESH                 6532765
# JAMMU AND KASHMIR                3566674
# TRIPURA                          3063903
# ...

# %%
Data.groupby("State_name")["Christians"].sum().sort_values(ascending=False)
# Out:
# State_name
# KERALA                         6141269
# TAMIL NADU                     4418331
# MEGHALAYA                      2213027
# NAGALAND                       1739651
# JHARKHAND                      1418608
# MANIPUR                        1179043
# ASSAM                          1165867
# ORISSA                         1161708
# KARNATAKA                      1142647
# ANDHRA PRADESH                 1129784
# MAHARASHTRA                    1080073
# MIZORAM                         956331
# WEST BENGAL                     658618
# CHHATTISGARH                    490542
# ARUNACHAL PRADESH               418732
# GOA                             366130
# UTTAR PRADESH                   356448
# PUNJAB                          348230
# GUJARAT                         316178
# MADHYA PRADESH                  213282
# TRIPURA                         159882
# NCT OF DELHI                    146093
# BIHAR                           129247
# RAJASTHAN                        96430
# ...

# %%
it=Data[Data.District_name=="Agra"]["Literate"]
it
# Out:
# 145    2680510
# Name: Literate, dtype: int64

# %%
Data[Data.State_name=="MAHARASHTRA"]["Male_Workers"].sum()
# Out:
# np.int64(32616875)

# %%
pp=Data[Data.District_name=="Agra"].Population.sum()
pp
# Out:
# np.int64(4418797)

# %%
pp-it
# Out:
# 145    1738287
# Name: Literate, dtype: int64
